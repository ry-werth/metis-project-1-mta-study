# %%
import numpy
import pandas as pd
import matplotlib as plt
import seaborn as sbn

# %%
mta_sept_05 = pd.read_csv('turnstile_200905.txt')
mta_aug_29 = pd.read_csv('turnstile_200829.txt')
mta_sept_12 = pd.read_csv('turnstile_200912.txt')
mta_sept_19 = pd.read_csv('turnstile_200919.txt')

# %%
mta_lastmonth = pd.concat([mta_aug_29, mta_sept_05, mta_sept_12, mta_sept_19])

# %%
import datetime
mta_lastmonth.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7447810
# 1  REGULAR  7447812
# 2  REGULAR  7447824
# 3  REGULAR  7447852
# 4  REGULAR  7447937
#
#    EXITS
# 0                                            2532191
# 1                                            2532197
# 2                                            2532208
# 3                                            2532248
# 4                                            2532276

# %%
mta_sept_05['datetime'] = pd.to_datetime(mta_sept_05['DATE'] + ' ' + mta_sept_05['TIME'])
mta_sept_05.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2020  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7450785
# 1  REGULAR  7450788
# 2  REGULAR  7450798
# 3  REGULAR  7450826
# 4  REGULAR  7450910
#
#    EXITS                                                                 \
# 0                                            2533372
# 1                                            2533375
# 2                                            2533391
# 3                                            2533423
# 4                                            2533454
#
#              datetime
# 0 2020-08-29 00:00:00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-fdde3aa30518> in <module>
# ----> 1 mta_lastmonth['datetime'] = mta_lastmonth['DATE'] + mta_lastmonth['TIME']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1047
#    1048         if is_datetime64_dtype(left) or is_datetime64tz_dtype(left):
# -> 1049             result = dispatch_to_index_op(op, left, right, pd.DatetimeIndex)
#    1050             return construct_result(left, result,
#    1051                                     index=left.index, name=res_name,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1099         left_idx = left_idx._shallow_copy(freq=None)
#    1100     try:
# -> 1101         result = op(left_idx, right)
#    1102     except NullFrequencyError:
# ...
