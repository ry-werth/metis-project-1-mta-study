# %%
import pandas as pd

# %%
df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_191026.txt')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205595 entries, 0 to 205594
# Data columns (total 11 columns):
# C/A                                                                     205595 non-null object
# UNIT                                                                    205595 non-null object
# SCP                                                                     205595 non-null object
# STATION                                                                 205595 non-null object
# LINENAME                                                                205595 non-null object
# DIVISION                                                                205595 non-null object
# DATE                                                                    205595 non-null object
# TIME                                                                    205595 non-null object
# DESC                                                                    205595 non-null object
# ...

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/19/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/19/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/19/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/19/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/19/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7238905
# 1  REGULAR  7238924
# 2  REGULAR  7238945
# 3  REGULAR  7239029
# 4  REGULAR  7239280
#
#    EXITS
# 0                                            2452500
# 1                                            2452505
# 2                                            2452536
# 3                                            2452602
# 4                                            2452651

# %%
len(df.STATION.unique())
# Out:
# 377

# %%
len(df.UNIT.unique())
# Out:
# 468

# %%
type(df["DATE"][0])
# Out:
# str

# %%
df["DATE"] = pd.to_datetime(df["DATE"])

# %%
df["DAY"] = df["DATE"].dt.dayofweek

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7238905
# 1  REGULAR  7238924
# 2  REGULAR  7238945
# 3  REGULAR  7239029
# 4  REGULAR  7239280
#
#    EXITS                                                                 DAY
# 0                                            2452500                       5
# 1                                            2452505                       5
# 2                                            2452536                       5
# 3                                            2452602                       5
# ...

# %%
day_dict = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

# %%
df["DAY_STR"] = df["DAY"].map(day_dict)
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-10-19  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7238905
# 1  REGULAR  7238924
# 2  REGULAR  7238945
# 3  REGULAR  7239029
# 4  REGULAR  7239280
#
#    EXITS                                                                 DAY  \
# 0                                            2452500                       5
# 1                                            2452505                       5
# 2                                            2452536                       5
# 3                                            2452602                       5
# ...

# %%
df = df.sort_values(by=['STATION', 'UNIT', 'DATE'])
df
# Out:
#          C/A  UNIT       SCP    STATION LINENAME DIVISION       DATE  \
# 32094   H007  R248  00-00-00       1 AV        L      BMT 2019-10-19
# 32095   H007  R248  00-00-00       1 AV        L      BMT 2019-10-19
# 32096   H007  R248  00-00-00       1 AV        L      BMT 2019-10-19
# 32097   H007  R248  00-00-00       1 AV        L      BMT 2019-10-19
# 32098   H007  R248  00-00-00       1 AV        L      BMT 2019-10-19
# ...      ...   ...       ...        ...      ...      ...        ...
# 180900  R419  R326  00-05-01  ZEREGA AV        6      IRT 2019-10-25
# 180901  R419  R326  00-05-01  ZEREGA AV        6      IRT 2019-10-25
# 180902  R419  R326  00-05-01  ZEREGA AV        6      IRT 2019-10-25
# 180903  R419  R326  00-05-01  ZEREGA AV        6      IRT 2019-10-25
# 180904  R419  R326  00-05-01  ZEREGA AV        6      IRT 2019-10-25
#
#             TIME     DESC   ENTRIES  \
# 32094   00:00:00  REGULAR  15075246
# 32095   04:00:00  REGULAR  15075444
# ...

# %%
df['ENTRIES_DIFF']=df.groupby(['STATION', 'UNIT'])['ENTRIES'].diff().fillna(-1)
df.head()
# Out:
#         C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 32094  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  00:00:00
# 32095  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  04:00:00
# 32096  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  08:00:00
# 32097  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  12:00:00
# 32098  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  16:00:00
#
#           DESC   ENTRIES     EXITS  DAY   DAY_STR  ENTRIES_DIFF
# 32094  REGULAR  15075246  16848101    5  Saturday          -1.0
# 32095  REGULAR  15075444  16848361    5  Saturday         198.0
# 32096  REGULAR  15075520  16848613    5  Saturday          76.0
# 32097  REGULAR  15075748  16849236    5  Saturday         228.0
# 32098  REGULAR  15076331  16850112    5  Saturday         583.0

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'DAY', 'DAY_STR', 'ENTRIES_DIFF'],
#       dtype='object')

# %%
df = df.rename(columns={'EXITS                                                               ': 'EXITS'})

# %%
df['EXIT_DIFF']=df.groupby(['STATION', 'UNIT'])['EXITS'].diff().fillna(-1)
df.head()
# Out:
#         C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 32094  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  00:00:00
# 32095  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  04:00:00
# 32096  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  08:00:00
# 32097  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  12:00:00
# 32098  H007  R248  00-00-00    1 AV        L      BMT 2019-10-19  16:00:00
#
#           DESC   ENTRIES     EXITS  DAY   DAY_STR  ENTRIES_DIFF  EXIT_DIFF
# 32094  REGULAR  15075246  16848101    5  Saturday          -1.0       -1.0
# 32095  REGULAR  15075444  16848361    5  Saturday         198.0      260.0
# 32096  REGULAR  15075520  16848613    5  Saturday          76.0      252.0
# 32097  REGULAR  15075748  16849236    5  Saturday         228.0      623.0
# 32098  REGULAR  15076331  16850112    5  Saturday         583.0      876.0

# %%
# Out:
# 32094     16848101
# 32095     16848361
# 32096     16848613
# 32097     16849236
# 32098     16850112
#             ...
# 180900         160
# 180901         160
# 180902         160
# 180903         160
# 180904         160
# Name: EXITS, Length: 205595, dtype: int64
