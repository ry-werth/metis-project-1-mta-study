# %% [markdown]
# ## Finding the juiciest targets:
# """Here are the 10 wealthiest neighborhoods in New York City
# 1. Turtle Bay/East Midtown: $196,721.
# 2. Lincoln Square: $188,144.
# 3. Battery Park City/Lower Manhattan: $185,275.
# 4. Midtown/Midtown South: $184,315.
# 5. Hudson Yards/Chelsea/Flatiron District/Union Square: $182,129.
# 6. West Village: $180,247.
# 7. Brooklyn Heights/Cobble Hill: $169,555.
# 8. Upper West Side: $161,30."""
# from https://www.6sqft.com/the-wealthiest-neighborhoods-in-new-york-city/
#
# Top universities from quick search on Google for tech field:
# * Columbia
# * NYU
# * Barnard (Women's College!)
# * Baruch
# * Fordham
# * St. John's
# * Queens College
# * CCNY
# https://www.google.com/search?q=universities+nyc&oq=universities+nyc&aqs=chrome..69i57.2469j0j7&sourceid=chrome&ie=UTF-8&ibp=htl;splinter&sa=X&ved=2ahUKEwieifnb4v_rAhWdIjQIHXhfBvcQiYsCKAJ6BAgKEBU&sxsrf=ALeKk02IXuAVE75Ue7CGTntJbZV1hM97Ng:1600881069808#htivrt=splinter&fpstate=tldetail&htichips=cip2:cip2_110000,cip2:cip2_260000,cip2:cip2_140000,cip2:cip2_270000,cip2:cip2_400000&htischips=cip2;cip2_110000;cip2_260000;cip2_140000;cip2_270000;cip2_400000&htidocid=X_S-FuPh1kYFti8GAAAAAA%3D%3D
#
# Tech areas:
# * Silicon Alley (Flatiron)
# * Soho
# * Industry City
# * Yonkers
# * Long Island City
# * DUMBO
# https://www.builtinnyc.com/2018/04/10/nyc-tech-neighborhoods
# https://theculturetrip.com/north-america/usa/new-york/articles/new-yorks-tech-neighborhoods-soho/
#
# ### Google Maps of targets, best subway stops (in neighborhood or within 10 m walk)
# Google maps search for target then add "subway station near " to front
#
# #### Flatiron neighborhood (primary tech hub and 5th in income):
# * 23 Street Station
# * 28 Street
# * 1 Avenue
#
# #### Near NYU:
# * 8 Street
# * Bleeker ST
# * W 4 St - Wash Sq
#
# #### Near Columbia:
# * 116 St Station - Columbia University
# * Cathedral Parkway 110 St
#
# #### Near Barnard: see Columbia
#
# #### Near Baruch:
# * 23 St
# * 28 St Station
# * 23 St Station
#
# #### Near Fordham:
# * Fordham
#
# #### Near CCNY:
# * 135 St
# * 137 St - City College
# * 145 St
#
# #### In Turtle Bay (1st in income):
# * 57 Street Subway Station
# * 47-50 Sts-Rockefeller Ctr
# * 5 Avenue-53 St Station
# * Grand Central - 42 St
# * 72 Street Subway Station
# * 51 St Station
# * 59 St-Lexington Av
# * 5 Avenue-Bryant Park Station - not an MTA stop but 42nd St-Bryant Park station is around corner
# * Roosevelt Island Subway Station
# * 5 Avenue Station
# * -7th Ave/53rd Street Subway Station-
# * 59 St - Columbus Circle Station
# * 33 Street Station
# * 66 St-Lincoln Ctr
# * Lexington Av-63 Street Subway Station
# * 57 Street
# * Times Sq-42 St
# * Vernon Boulevard-Jackson Avenue Station
# * Grand Central Terminal
# * 59 St - Lexington Av Station
#
# #### In Lincoln Square (2nd in income):
# * 66 St-Lincoln Center
# * 96 Street Station
# * Times Sq-42 St
# * 72 Street Subway Station
# * 34th Street Hudson Yards Subway Station
# * 5 Ave-53 St Station
# * 1 Ave
# * 47-50 Sts-Rockefeller Ctr
# * 86th St
# * W 4 St - Wash Sq
#
# #### In Battery Park City (3rd in income):
# * Whitehall Street - South Ferry
# * World Trade Center
# * Fulton Street Subway Station
# * WTC Cortlandt
# * Fulton St
# * Wall Street Station
# * Wall Street Station
# * Chambers Street Station
# * Franklin Street Station
# * Fulton Street Station
# * Bowling Green
#
# #### In Midtown (4th in income):
# * 34th St-Hudson Yards Subway Station
# * Times Sq-42 St
# * 42 St-Bryant Park Station
# * 47-50 Sts-Rockefeller Ctr
# * 57 Street Subway Station
# * Times Sq-42 St Station
# * 42 St-Port Authority
# * 34 St - Herald Sq Subway Station
# * 50 Street Station
# * 28 Street
# * 5 Avenue-53 St Station
# * 34 St - Penn Station
# * 23 Street Station
# * Eighth Avenue - Fourteenth Street
# * 5 Avenue-Bryant Park Station - doesn't correspond to an MTA spot but is within a block of 42nd St-Bryant Park Station
# * 50 Street Subway Station
# * 5 Avenue Station
# * 49 St Subway Station
# * Grand Central - 42 St
# * 14 Street Station
#
# #### In West Village (6th in income):
# * W 4 St - Wash Sq
# * 14 Street Station
# * Houston St
# * Eighth Avenue - Fourteenth Street
# * 14 Street Station
# * Astor Pl
# * Christopher St Station
# * 42 St-Bryant Park Station
# * 34 St - Herald Sq Subway Station
# * Bleecker St Station
# * Prince St Station
# * Times Sq-42 St Station
# * Spring Street Subway Station
# * Delancey St · Essex St Subway
# * 34th St-Hudson Yards Subway Station
# * 14 St - Union Sq
# * Canal St Station
# * 34 St - Penn Station
#
# #### In SoHo (secondary tech hub):
# * Canal St Station
# * Prince St Station
# * Houston St
# * W 4 St - Wash Sq
# * 8 Street Station
# * Delancey St · Essex St Subway
# * Franklin Street Station
# * Spring Street Subway Station
# * Spring Street
# * Bleecker St Station
# * World Trade Center
# * Fulton Street Subway Station
# * Astor Pl
# * Chambers Street Station
# * Broadway-Lafayette Street Station B, D, F, M, 6
# * Bowery
# * Brooklyn Bridge - City Hall Subway Station
# * WTC Cortlandt
# * 14 Street Station
# * Eighth Avenue - Fourteenth Street
#
# #### In DUMBO (secondary tech hub):
# * York Street Subway Station
# * High Street - Brooklyn Bridge
# * Fulton Street Subway Station
# * Clark St
# * Brooklyn Bridge - City Hall Subway Station
# * DeKalb Av
#
# #### In Industry City (secondary tech hub):
# * 36 Street Station
# * 45 St
# * 59 Street Station
# * 53 St
# * 25 St
# * Prospect Av Station
# * Smith-9th Streets
# * 15 St - Prospect Park Station
# * 9 Avenue
# * Fort Hamilton Parkway Station
# * -4 Av-
# * 8 Avenue Station
# * Fort Hamilton Parkway Station
# * DeKalb Av
# * Church Av
# * Bay Ridge Av Station
# * 7 Av
# * Grand Army Plaza Station
# * 9 Street Station
# * Newkirk Plaza Subway Station
#
# #### In Yonkers (secondary tech hub):
# * -Yonkers Station-
# * -241 Street-
# * -Nereid Av-
#
# #### In Long Island City (secondary tech hub):
# * Vernon Boulevard-Jackson Avenue Station
# * Queens Plaza
# * Queensboro Plaza
# * Hunters Point Avenue
# * Court Square Station
# * 21 St-Queensbridge Sta
# * Steinway St
# * Hunterspoint Avenue
# * 30 Av
# * 21 Street-Van Alst Station
# * 33 St - Rawson St

# %%
#Used text app to search and replace for list creation
uni = ['8 Street', 'Bleeker ST', 'W 4 St - Wash Sq', '116 St Station - Columbia University', 'Cathedral Parkway 110 St', '23 St', '28 St Station', '23 St Station', 'Fordham', '135 St', '137 St - City College', '145 St']

tech = ['23 Street Station', '28 Street', '1 Avenue', 'Canal St Station', 'Prince St Station', 'Houston St', 'W 4 St - Wash Sq', '8 Street Station', 'Delancey St · Essex St Subway', 'Franklin Street Station', 'Spring Street Subway Station', 'Spring Street', 'Bleecker St Station', 'World Trade Center', 'Fulton Street Subway Station', 'Astor Pl', 'Chambers Street Station', 'Broadway-Lafayette Street Station B, D, F, M, 6', 'Bowery', 'Brooklyn Bridge - City Hall Subway Station', 'WTC Cortlandt', '14 Street Station', 'Eighth Avenue - Fourteenth Street', 'York Street Subway Station', 'High Street - Brooklyn Bridge', 'Fulton Street Subway Station', 'Clark St', 'Brooklyn Bridge - City Hall Subway Station', 'DeKalb Av', '36 Street Station', '45 St', '59 Street Station', '53 St', '25 St', 'Prospect Av Station', 'Smith-9th Streets', '15 St - Prospect Park Station', '9 Avenue', 'Fort Hamilton Parkway Station', '8 Avenue Station', 'Fort Hamilton Parkway Station', 'DeKalb Av', 'Church Av', 'Bay Ridge Av Station', '7 Av', 'Grand Army Plaza Station', '9 Street Station', 'Newkirk Plaza Subway Station', 'Vernon Boulevard-Jackson Avenue Station', 'Queens Plaza', 'Queensboro Plaza', 'Hunters Point Avenue', 'Court Square Station', '21 St-Queensbridge Sta', 'Steinway St', 'Hunterspoint Avenue', '30 Av', '21 Street-Van Alst Station', '33 St - Rawson St']

rich = ['57 Street Subway Station', '47-50 Sts-Rockefeller Ctr', '5 Avenue-53 St Station', 'Grand Central - 42 St', '72 Street Subway Station', '51 St Station', '59 St-Lexington Av', '5 Avenue-Bryant Park Station', 'Roosevelt Island Subway Station', '5 Avenue Station', '59 St - Columbus Circle Station', '33 Street Station', '66 St-Lincoln Ctr', 'Lexington Av-63 Street Subway Station', '57 Street', 'Times Sq-42 St', 'Vernon Boulevard-Jackson Avenue Station', 'Grand Central Terminal', '59 St - Lexington Av Station', '66 St-Lincoln Center', '96 Street Station', 'Times Sq-42 St', '72 Street Subway Station', '34th Street Hudson Yards Subway Station', '5 Ave-53 St Station', '1 Ave', '47-50 Sts-Rockefeller Ctr', '86th St', 'W 4 St - Wash Sq', 'Whitehall Street - South Ferry', 'World Trade Center', 'Fulton Street Subway Station', 'WTC Cortlandt', 'Fulton St', 'Wall Street Station', 'Wall Street Station', 'Chambers Street Station', 'Franklin Street Station', 'Fulton Street Station', 'Bowling Green', '34th St-Hudson Yards Subway Station', 'Times Sq-42 St', '42 St-Bryant Park Station', '47-50 Sts-Rockefeller Ctr', '57 Street Subway Station', 'Times Sq-42 St Station', '42 St-Port Authority', '34 St - Herald Sq Subway Station', '50 Street Station', '28 Street', '5 Avenue-53 St Station', '34 St - Penn Station', '23 Street Station', 'Eighth Avenue - Fourteenth Street', '5 Avenue-Bryant Park Station', '50 Street Subway Station', '5 Avenue Station', '49 St Subway Station', 'Grand Central - 42 St', '14 Street Station', '23 Street Station', '28 Street', '1 Avenue', 'W 4 St - Wash Sq', '14 Street Station', 'Houston St', 'Eighth Avenue - Fourteenth Street', '14 Street Station', 'Astor Pl', 'Christopher St Station', '42 St-Bryant Park Station', '34 St - Herald Sq Subway Station', 'Bleecker St Station', 'Prince St Station', 'Times Sq-42 St Station', 'Spring Street Subway Station', 'Delancey St · Essex St Subway', '34th St-Hudson Yards Subway Station', '14 St - Union Sq', 'Canal St Station', '34 St - Penn Station']

uni = sorted(uni)
tech = sorted(tech)
rich = sorted(rich)

# %%
unified_list = sorted(list(set(uni) | set(tech) | set(rich)))
unified_list
# Out:
# ['1 Ave',
#  '1 Avenue',
#  '116 St Station - Columbia University',
#  '135 St',
#  '137 St - City College',
#  '14 St - Union Sq',
#  '14 Street Station',
#  '145 St',
#  '15 St - Prospect Park Station',
#  '21 St-Queensbridge Sta',
#  '21 Street-Van Alst Station',
#  '23 St',
#  '23 St Station',
#  '23 Street Station',
#  '25 St',
#  '28 St Station',
#  '28 Street',
#  '30 Av',
#  '33 St - Rawson St',
#  '33 Street Station',
#  '34 St - Herald Sq Subway Station',
#  '34 St - Penn Station',
#  '34th St-Hudson Yards Subway Station',
#  '34th Street Hudson Yards Subway Station',
#  '36 Street Station',
#  '42 St-Bryant Park Station',
#  '42 St-Port Authority',
#  '45 St',
#  '47-50 Sts-Rockefeller Ctr',
#  '49 St Subway Station',
#  '5 Ave-53 St Station',
#  '5 Avenue Station',
#  '5 Avenue-53 St Station',
#  '5 Avenue-Bryant Park Station',
#  '50 Street Station',
#  '50 Street Subway Station',
#  '51 St Station',
#  '53 St',
#  '57 Street',
#  '57 Street Subway Station',
# ...

# %%
import pandas as pd
turnstiles_df = pd.read_csv('turnstile_200829.txt')

# %%
stations_list = sorted(list(turnstiles_df['STATION'].unique()))
stations_list
# Out:
# ['1 AV',
#  '103 ST',
#  '103 ST-CORONA',
#  '104 ST',
#  '110 ST',
#  '111 ST',
#  '116 ST',
#  '116 ST-COLUMBIA',
#  '121 ST',
#  '125 ST',
#  '135 ST',
#  '137 ST CITY COL',
#  '138/GRAND CONC',
#  '14 ST',
#  '14 ST-UNION SQ',
#  '145 ST',
#  '149/GRAND CONC',
#  '14TH STREET',
#  '15 ST-PROSPECT',
#  '155 ST',
#  '157 ST',
#  '161/YANKEE STAD',
#  '163 ST-AMSTERDM',
#  '167 ST',
#  '168 ST',
#  '169 ST',
#  '170 ST',
#  '174 ST',
#  '174-175 STS',
#  '175 ST',
#  '176 ST',
#  '18 AV',
#  '18 ST',
#  '181 ST',
#  '182-183 STS',
#  '183 ST',
#  '190 ST',
#  '191 ST',
#  '2 AV',
#  '20 AV',
#  '207 ST',
#  '21 ST',
#  '21 ST-QNSBRIDGE',
#  '215 ST',
#  '219 ST',
#  '225 ST',
#  '23 ST',
#  '231 ST',
#  '233 ST',
#  '238 ST',
#  '25 AV',
#  '25 ST',
#  '28 ST',
#  '3 AV',
#  '3 AV 138 ST',
#  '3 AV-149 ST',
#  '30 AV',
#  '33 ST',
#  '33 ST-RAWSON ST',
#  '34 ST-HERALD SQ',
#  '34 ST-HUDSON YD',
#  '34 ST-PENN STA',
#  '36 AV',
#  '36 ST',
#  '39 AV',
#  '4 AV-9 ST',
# ...

# %%
station_translation = {'1 Ave': '1 AV', '1 Avenue': '1 AV', '116 St Station - Columbia University': '116 ST-COLUMBIA',
                       '135 St': '135 ST', '137 St - City College': '137 ST CITY COL', 
                       '14 St - Union Sq': '14 ST-UNION SQ', '14 Street Station': '14 ST', '145 St': '145 ST',
                       '15 St - Prospect Park Station': '15 ST-PROSPECT', '21 St-Queensbridge Sta': '21 ST-QNSBRIDGE', 
                       '21 Street-Van Alst Station': '21 ST', '23 St': '23 ST', '23 St Station': '23 ST', 
                       '23 Street Station': '23 ST', '25 St': '25 ST', '28 St Station': '28 ST', '28 Street': '28 ST', 
                       '30 Av': '30 AV', '33 St - Rawson St': '33 ST-RAWSON ST', '33 Street Station': '33 ST', 
                       '34 St - Herald Sq Subway Station': '34 ST-HERALD SQ', '34 St - Penn Station': '34 ST-PENN STA', 
                       '34th St-Hudson Yards Subway Station': '34 ST-HUDSON YD', 
                       '34th Street Hudson Yards Subway Station': '34 ST-HUDSON YD', '36 Street Station': '36 ST', 
                       '42 St-Bryant Park Station': '42 ST-BRYANT PK', '42 St-Port Authority': '42 ST-PORT AUTH', 
                       '45 St': '45 ST', '47-50 Sts-Rockefeller Ctr': '47-50 STS ROCK', 
                       '49 St Subway Station': '49 ST', '5 Ave-53 St Station': '5 AV/53 ST', 
                       '5 Avenue Station': '5 AVE', '5 Avenue-53 St Station': '5 AV/53 ST', 
                       '5 Avenue-Bryant Park Station': '42 ST-BRYANT PK', '50 Street Station': '50 ST', 
                       '50 Street Subway Station': '50 ST', '51 St Station': '51 ST', '53 St': '53 ST', 
                       '57 Street': '57 ST', '57 Street Subway Station': '57 ST', 
                       '59 St - Columbus Circle Station': '59 ST COLUMBUS', 
                       '59 St - Lexington Av Station': '59 ST', #stations connected
                       '59 St-Lexington Av': '59 ST', '59 Street Station': '59 ST', 
                       '66 St-Lincoln Center': '66 ST-LINCOLN', '66 St-Lincoln Ctr': '66 ST-LINCOLN', 
                       '7 Av': '7 AV', '72 Street Subway Station': '72 ST', 
                       '8 Avenue Station': '8 AV', '8 Street': '8 ST-NYU', '8 Street Station': '8 ST-NYU', 
                       '86th St': '86 ST', '9 Avenue': '9 AV', '9 Street Station': '9TH STREET', 
                       '96 Street Station': '96 ST', 'Astor Pl': 'ASTOR PL', 'Bay Ridge Av Station': 'BAY RIDGE AV', 
                       'Bleecker St Station': 'BLEECKER ST', 'Bleeker ST': 'BLEECKER ST', 'Bowery': 'BOWERY', 
                       'Bowling Green': 'BOWLING GREEN', 
                       'Broadway-Lafayette Street Station B, D, F, M, 6': 'BLEECKER ST', #stations connected
                       'Brooklyn Bridge - City Hall Subway Station': 'BROOKLYN BRIDGE', 
                       'Canal St Station': 'CANAL ST', 'Cathedral Parkway 110 St': 'CATHEDRAL PKWY', 
                       'Chambers Street Station': 'CHAMBERS ST', 'Christopher St Station': 'CHRISTOPHER ST', 
                       'Church Av': 'CHURCH AV', 'Clark St': 'CLARK ST', 'Court Square Station': 'COURT SQ', 
                       'DeKalb Av': 'DEKALB AV', 'Delancey St · Essex St Subway': 'DELANCEY/ESSEX', 
                       'Eighth Avenue - Fourteenth Street': '14 ST', #possibly bad map data; closest stop
                       'Fordham': 'FORDHAM RD', 'Fort Hamilton Parkway Station': 'FT HAMILTON PKY', 
                       'Franklin Street Station': 'FRANKLIN ST', 'Fulton St': 'FULTON ST', 
                       'Fulton Street Station': 'FULTON ST', 'Fulton Street Subway Station': 'FULTON ST', 
                       'Grand Army Plaza Station': 'GRAND ARMY PLAZ', 'Grand Central - 42 St': 'GRD CNTRL-42 ST', 
                       'Grand Central Terminal': 'GRD CNTRL-42 ST', 'High Street - Brooklyn Bridge': 'HIGH ST', 
                       'Houston St': 'HOUSTON ST', 'Hunters Point Avenue': 'HUNTERS PT AV', 
                       'Hunterspoint Avenue': 'HUNTERS PT AV', 
                       'Lexington Av-63 Street Subway Station': 'LEXINGTON AV/63', 
                       'Newkirk Plaza Subway Station': 'NEWKIRK PLAZA', 'Prince St Station': 'PRINCE ST', 
                       'Prospect Av Station': 'PROSPECT AV', 'Queens Plaza': 'QUEENS PLAZA', 
                       'Queensboro Plaza': 'QUEENSBORO PLZ', 'Roosevelt Island Subway Station': 'ROOSEVELT ISLND', 
                       'Smith-9th Streets': 'SMITH-9 ST', 'Spring Street': 'SPRING ST', 
                       'Spring Street Subway Station': 'SPRING ST', 'Steinway St': 'STEINWAY ST', 
                       'Times Sq-42 St': 'TIMES SQ-42 ST', 'Times Sq-42 St Station': 'TIMES SQ-42 ST', 
                       'Vernon Boulevard-Jackson Avenue Station': 'VERNON-JACKSON', 
                       'W 4 St - Wash Sq': 'W 4 ST-WASH SQ', 'WTC Cortlandt': 'WTC-CORTLANDT', 
                       'Wall Street Station': 'WALL ST', 'Whitehall Street - South Ferry': 'WHITEHALL S-FRY', 
                       'World Trade Center': 'WORLD TRADE CTR', 'York Street Subway Station': 'YORK ST'}

# %%
uni = [station_translation[x] for x in uni]
tech = [station_translation[x] for x in tech]
rich = [station_translation[x] for x in rich]
unified_list = sorted(list(set(uni) | set(tech) | set(rich)))

# %%
# Is a given station in the unified list also present in
uni_in = [(x in uni) for x in unified_list]
tech_in = [(x in tech) for x in unified_list]
rich_in = [(x in rich) for x in unified_list]

# %%
stations_in = pd.DataFrame()
stations_in['stations'] = unified_list
stations_in['university'] = uni_in
stations_in['tech'] = tech_in
stations_in['rich'] = rich_in

# %%
stations_score = stations_in
uni_scoring = 4
tech_scoring = 2
rich_scoring = 1
stations_score['total score'] = (stations_score['university']*uni_scoring 
                                + stations_score['tech']*tech_scoring
                                + stations_score['rich']*rich_scoring)

# %%
stations_score.sort_values(by = 'total score', ascending = False)
# Out:
#           stations  university   tech   rich  total score
# 12           28 ST        True   True   True            7
# 78  W 4 ST-WASH SQ        True   True   True            7
# 44     BLEECKER ST        True   True   True            7
# 10           23 ST        True   True   True            7
# 37        8 ST-NYU        True   True  False            6
# ..             ...         ...    ...    ...          ...
# 26           5 AVE       False  False   True            1
# 46   BOWLING GREEN       False  False   True            1
# 51  CHRISTOPHER ST       False  False   True            1
# 18  34 ST-PENN STA       False  False   True            1
# 25      5 AV/53 ST       False  False   True            1
#
# [84 rows x 5 columns]
